# %%
import os
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import plotly.graph_objs as go
from plotly.subplots import make_subplots
import plotly.offline as pyo
import random

# %%
df = pd.read_csv("C:\\Users\\Anast\\OneDrive\\Documents\\personal\\Zuza\\data_graph.csv")

# %%
df
# Out:
#       time     D
# 0     0.67 -0.35
# 1     1.00 -0.69
# 2     1.33 -0.33
# 3     1.67  0.02
# 4     2.00  0.02
# ..     ...   ...
# 114  38.67 -2.05
# 115  39.00 -1.36
# 116  39.33 -1.24
# 117  39.67 -3.97
# 118  40.00 -0.95
#
# [119 rows x 2 columns]

# %%
x = df["time"]
y = df["D"]
colors = [1, 2, 3]

plt.plot(x, y, color="black")
plt.axvspan(xmin=0, xmax=3.7, color="#62B5E5", alpha=0.3)
plt.axvspan(xmin=3.7, xmax=8, color="#FF9933", alpha=0.3)
plt.axvspan(xmin=8, xmax=50, color="#66FFB2", alpha=0.3)
plt.axvline(x = 8, ymax=0.925, color = "red", linestyle=":", label = 'axvline - full height')
plt.xlim([0, x.max()])
plt.ylim([0, y.max() + 5])
plt.fill_between(x, y, where=(x>=3) & (x<=27), hatch='//', alpha=0.6, facecolor="none")

plt.xlabel("Time (minutes)")
plt.ylabel("Thrombin (nM)")
plt.title("Thrombin Generation Assay")
# Out:
# Text(0.5, 1.0, 'Thrombin Generation Assay')
